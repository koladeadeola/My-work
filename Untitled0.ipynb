# %% [markdown]
# <a href="https://colab.research.google.com/github/koladeadeola/My-work/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("STUDENT PERFORMANCE ANALYZER")
print ("Kolade Adeola")
age = 40
print (age)
print ("Guidance and councelling Education")
m = 90
p = 80
s = 70
total = m + p + s
print (total)
a = 1
b = 1
c = 1
t = a + b + c
print (t)
average = total / t
print (average)
highestscore = 90
print (highestscore)
lowestscore = 70
print (lowestscore)
passed = True
print (passed)
# Out:
# STUDENT PERFORMANCE ANALYZER
# Kolade Adeola
# 40
# Guidance and councelling Education
# 240
# 3
# 80.0
# 90
# 70
# True
